# %% [markdown]
# # VICTOR
# ## Data analyst student

# %% [markdown]
# # INTRODUCTION TO PYTHON
# ## This is my first script

# %%
print("hello world")
# Out:
# hello world

# %%
1+1
# Out:
# 2

# %%
print( 5+10)
# Out:
# 15

# %% [markdown]
# # python data types

# %% [markdown]
# # 1 INTEGER

# %%
X =20 #integer  
X
# Out:
# 20

# %% [markdown]
# # 2.FLOAT

# %%
Y= 3.14   # float
print(Y)
# Out:
# 3.14

# %% [markdown]
# # 3.STRING; REPRESENT SEQUENCE OF CHARACTERS

# %%
name='victor munene' # string
print (name)
# Out:
# victor munene

# %%
greeting ='hello'
print (greeting)
# Out:
# hello

# %% [markdown]
# # 4.Boolean;Represents true or false values

# %%
is_valid = True    #Boolean
is_valid
# Out:
# True

# %%
is_valid = False   #Boolean
is_valid
# Out:
# False

# %%
is_valid = True  #Boolean
print (is_valid)
# Out:
# True

# %% [markdown]
# # 5.LIST;An Ordered ,mutable collection of items

# %%
fruits = ["apple","banana","orange" ]
print (fruits)
# Out:
# ['apple', 'banana', 'orange']

# %%
fruits = ["apple","banana","orange"]
print (fruits[0]) # Access first element
print (fruits[1]) # Access second element
print (fruits[2]) # Access third element
# Out:
# apple
# banana
# orange

# %% [markdown]
# # 6.TUPLE :An ordered,immutable collection of items

# %%
my_tuple = (1,2,3,"John" , True)
my_tuple
# Out:
# (1, 2, 3, 'John', True)

# %% [markdown]
# # 7.SET:An unordered mutable collection of unique items

# %%
my_set = (1,2,3,"john")
print (my_set)
# Out:
# (1, 2, 3, 'john')

# %% [markdown]
# # 8.DICTIONARY:A collection of key value pairs

# %%
my_dict = {
    "Name" : "John",
    "age" : "20",
    "gender" : "male",
    "occupation" : "data analyst"}
my_dict
# Out:
# {'Name': 'John', 'age': '20', 'gender': 'male', 'occupation': 'data analyst'}

# %%
person ={
    "name" :"victor munene",
    "age" : "19",
"occupation" : "teacher"}
person
# Out:
# {'name': 'victor munene', 'age': '19', 'occupation': 'teacher'}

# %% [markdown]
# # 10. WHAT ARE CONDITIONAL STATEMENTS
# ## 1: IF STATEMENT [do something if true]

# %%
age =18
if age >=18:
    print("you are an adult")
# Out:
# you are an adult

# %% [markdown]
# ## 2.if else statement(do one thing or minor)

# %%
age =25
if age >=18:
    print("you are an adult")
else:
    print("you are minor")
# Out:
# you are an adult

# %% [markdown]
# ## 3.If-elif-else statement(multiple conditions)

# %%
age = 18
if age >=18:
    print ("adult")
else:
    print ("minor")
# Out:
# adult

# %%
age = 15
if age >=18:
    print ("adult")
else:
    print ("minor")
# Out:
# minor

# %%
age = 30
if age >=18:
    print ("adult")
else:
    print ("minor")
# Out:
# adult

# %%
age = 25
if age >=20:
   print ('adult')
else:
  print ('minor')
# Out:
# adult

# %%
score = 85

if score >=90:
    print ("grade: A")
elif score >=80:
    print ("grade :B")
elif score >=70:
    print ("grade :C")
else :
    print("grade :F")
# Out:
# grade :B

# %%
score = 95

if score >=90:
    print ("grade: A")
elif score >=80:
    print ("grade :B")
elif score >=70:
    print ("grade :C")
else :
    print("grade :F")
# Out:
# grade: A

# %%
score = 60

if score >=90:
    print ("grade: A")
elif score >=80:
    print ("grade :B")
elif score >=70:
    print ("grade :C")
else :
    print("grade :F")
# Out:
# grade :F

# %% [markdown]
# ## 11.WHAT IS A LOOPS.....

# %%
# for loop
for i in range (5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# for loop
for i in range (3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
fruits=['apple','banana','cherry']
for fruit in fruits:
    print (fruit)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# # loop through a string

# %%
word ="python"
for letter in word:
    print(letter)
# Out:
# p
# y
# t
# h
# o
# n

# %%
word ="Victor"
for letter in word:
    print(letter)
# Out:
# V
# i
# c
# t
# o
# r

# %% [markdown]
# ## DATA SCIENCE EXAMPLE- loop through Dataframe

# %%
import pandas as pd
#create sample data
data ={
    'name' : ['Alice','Bob','Charlie'],
    'score' : [85,62,90]
}
df = pd.DataFrame(data)
# loop through rows
for index ,row in df.iterrows():
    print(f'{row['name']}) scored {row['score']}')
# Out:
# Alice) scored 85
# Bob) scored 62
# Charlie) scored 90

# %%
import pandas as pd
#create sample data
data ={
    'name' : ['Alice','Bob','Charlie'],
    'score' : [85,62,90]
}
df = pd.DataFrame(data)
df
# Out:
#       name  score
# 0    Alice     85
# 1      Bob     62
# 2  Charlie     90

# %% [markdown]
# ## 12.Functions

# %%
def greet(name) :
    return "Hello," + name
print(greet("Victor"))
# Out:
# Hello,Victor

# %% [markdown]
# ## 13.Install Necessary libraries

# %% [markdown]
# #!pip install pandas
# #!pip install numpy
# #!pip install seaborn
# #!pip install matplotlib
# #!pip install wordcloud
# #!pip install pillow
# #!pip install plotly.express

# %% [markdown]
# ## 14.Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # MATHEMATICAL OPERATIONS

# %% [markdown]
# ## 1. Basic aruthmetic operations

# %%
x = 10
y = 3

addition = x + y
substraction = x - y
multiplication = x * y
division = x/y
floor_division = x // y
modulus = x & y 
exponentiation = x ** y
print ( addition,substraction,multiplication,division,floor_division,modulus,exponentiation)
# Out:
# 13 7 30 3.3333333333333335 3 2 1000

# %%
import math

(square_root) = math.sqrt (25)
(absolute_value) = abs (8)
(power) = pow (3, 3)
(logarithm )= math.log (10)
log_base_10 = math.log10(100)
factorial = math. factorial (5)
print (square_root,absolute_value,power,logarithm,log_base_10,factorial)
# Out:
# 5.0 8 27 2.302585092994046 2.0 120

# %%
##

# %%
import math
num = 5.6789
rounded_value = round(num, 3)
floor_value = math.floor(num)
ceil_value = math.ceil(num)
print(rounded_value, floor_value ,ceil_value)
# Out:
# 5.679 5 6

# %% [markdown]
# ## WORKING WITH VECTORS IN PYTHON

# %%
import numpy as np
# creating a vector
vector_a = np.array([1,2,3])
vector_a
# Out:
# array([1, 2, 3])

# %%
vector_b = np.array ([4,5,6])
vector_b
# Out:
# array([4, 5, 6])

# %% [markdown]
# ## Vector addition

# %%
vector_sum= vector_a +vector_b
vector_sum
# Out:
# array([5, 7, 9])

# %% [markdown]
# ## Vector substraction

# %%
vector_sum= vector_a - vector_b
vector_sum
# Out:
# array([-3, -3, -3])

# %% [markdown]
# ## scalar multiplication

# %%
scalar_multiplication = 3* vector_a
scalar_multiplication
# Out:
# array([3, 6, 9])

# %% [markdown]
# ## Dot Product

# %%
dot_product = np.dot(vector_a , vector_b)
dot_product
print('Dot product:', dot_product)
# Out:
# Dot product: 32

# %% [markdown]
# ## Magnitude of a vector

# %%
import numpy as np
magnitude_a = np.linalg.norm(vector_a)
magnitude_a
rounded_magnitude_value= round (magnitude_a,3)
rounded_magnitude_value
print('magnitude:',rounded_magnitude_value)
# Out:
# magnitude: 3.742

# %% [markdown]
# ## Working with lists in python

# %%
fruits=['Apple','Banana','Cherry','Date']
fruits
# Out:
# ['Apple', 'Banana', 'Cherry', 'Date']

# %%
first_fruit = fruits [0]
first_fruit
# Out:
# 'Apple'

# %%
last_fruit = fruits [-1]
last_fruit
# Out:
# 'Date'

# %% [markdown]
# ## modifying elements

# %%
fruits[1] = 'Blueberry'
fruits
# Out:
# ['Apple', 'Blueberry', 'Cherry', 'Date']

# %% [markdown]
# ## Adding elements

# %%
fruits.append ('Elderberry')
fruits.insert(2, 'Coconut')

# %% [markdown]
# ## Removing elements

# %%
deleted_fruit = fruits.pop (3)
fruits.remove('Date')
fruits
# Out:
# ['Apple', 'Blueberry', 'Coconut', 'Elderberry']

# %% [markdown]
# ## list slicing

# %%
subset_fruits = fruits[1:3]
subset_fruits
# Out:
# ['Blueberry', 'Coconut']

# %% [markdown]
# ## iterating over a list

# %%
for fruit in fruits:
    print(fruit)
# Out:
# Apple
# Blueberry
# Coconut
# Elderberry

# %% [markdown]
# ## Sorting a list

# %%
fruits.sort()
fruits
# Out:
# ['Apple', 'Blueberry', 'Coconut', 'Elderberry']

# %% [markdown]
# ## finding the length of a list

# %%
num_fruits =len(fruits)
num_fruits
# Out:
# 4

# %%
print('updated fruits list:',fruits)
# Out:
# updated fruits list: ['Apple', 'Blueberry', 'Coconut', 'Elderberry']

# %%
print('deleted fruits:',deleted_fruit)
# Out:
# deleted fruits: Cherry

# %%
print('subset of fruuits:',subset_fruits)
# Out:
# subset of fruuits: ['Blueberry', 'Coconut']

# %%
print('number of fruits:',num_fruits)
# Out:
# number of fruits: 4

# %% [markdown]
# # MATRICES

# %% [markdown]
# ## What is a matrix?

# %%
import numpy as np
# create two 2x2 matrices
A = np.array([[1,2],
              [3,4]])
B = np.array([[2,0],
               [1,2]])

# %%
# perfom operations
print('A + B = \ n' , A+B)
# Out:
# A + B = \ n [[3 2]
#  [4 6]]

# %%
print ('\nA - B =\n' , A - B)
# Out:
# A - B =
#  [[-1  2]
#  [ 2  2]]

# %%
print('\nA X B (element-wise) = \n' , A * B)
# Out:
# A X B (element-wise) =
#  [[2 0]
#  [3 8]]

# %%
print ('nA X B(matrix multiplication) = \n', A @ B)
# Out:
# nA X B(matrix multiplication) =
#  [[ 4  4]
#  [10  8]]

# %%
print('\nTranpose of A =\n', A.T)
# Out:
# Tranpose of A =
#  [[1 3]
#  [2 4]]

# %% [markdown]
# ## Create Data frame Using Pandas (most common)

# %%
import pandas as pd 
#creating a data frame

# %%
data = {'Name' : ['Victor','Blessy','Edwin','Vell','Allan'],
    'Age' : [20,18,19,17,21],
    'County' : [ 'embu','meru','Bomet','Nyeri','Nakuru']}
df = pd.DataFrame(data)
df
# Out:
#      Name  Age  County
# 0  Victor   20    embu
# 1  Blessy   18    meru
# 2   Edwin   19   Bomet
# 3    Vell   17   Nyeri
# 4   Allan   21  Nakuru

# %%
import pandas as pd
df = pd.DataFrame(data)
print(df.head())
# Out:
#      Name  Age  County
# 0  Victor   20    embu
# 1  Blessy   18    meru
# 2   Edwin   19   Bomet
# 3    Vell   17   Nyeri
# 4   Allan   21  Nakuru

# %% [markdown]
# ## Accessing columns

# %%
import pandas as pd
df['County']
# Out:
# 0      embu
# 1      meru
# 2     Bomet
# 3     Nyeri
# 4    Nakuru
# Name: County, dtype: object

# %%
import pandas as pd
df ['Name']
# Out:
# 0    Victor
# 1    Blessy
# 2     Edwin
# 3      Vell
# 4     Allan
# Name: Name, dtype: object

# %% [markdown]
# ## Accessing rows

# %%
print('\nAccessing first row:')
print(df.iloc[0])
# Out:
# Accessing first row:
# Name      Victor
# Age           20
# County      embu
# Name: 0, dtype: object

# %%
print('\nAccessing first row:')
print(df.iloc[1])
# Out:
# Accessing first row:
# Name      Blessy
# Age           18
# County      meru
# Name: 1, dtype: object

# %% [markdown]
# ## Adding a new column

# %%
df['Salary'] = [50000,70000,30000,60000,100000]
df['occupation']=['pilot','Nurse','Teacher','Dentist','politician']
df
# Out:
#      Name  Age  County  Salary  occupation
# 0  Victor   20    embu   50000       pilot
# 1  Blessy   18    meru   70000       Nurse
# 2   Edwin   19   Bomet   30000     Teacher
# 3    Vell   17   Nyeri   60000     Dentist
# 4   Allan   21  Nakuru  100000  politician

# %% [markdown]
# ## Filtering Data

# %%
print('\nFiltering rows where Age >18:')
# Out:
# Filtering rows where Age >18:

# %%
df[df['Age'] > 18]
# Out:
#      Name  Age  County  Salary  occupation
# 0  Victor   20    embu   50000       pilot
# 2   Edwin   19   Bomet   30000     Teacher
# 4   Allan   21  Nakuru  100000  politician

# %% [markdown]
# ## Sorting Data

# %%
df.sort_values(by='Age', ascending=False)
# Out:
#      Name  Age  County  Salary  occupation
# 4   Allan   21  Nakuru  100000  politician
# 0  Victor   20    embu   50000       pilot
# 2   Edwin   19   Bomet   30000     Teacher
# 1  Blessy   18    meru   70000       Nurse
# 3    Vell   17   Nyeri   60000     Dentist

# %%
df.sort_values(by='Age', ascending=True)
# Out:
#      Name  Age  County  Salary  occupation
# 3    Vell   17   Nyeri   60000     Dentist
# 1  Blessy   18    meru   70000       Nurse
# 2   Edwin   19   Bomet   30000     Teacher
# 0  Victor   20    embu   50000       pilot
# 4   Allan   21  Nakuru  100000  politician

# %% [markdown]
# ## Grouping Data

# %%
df.groupby('County')['Age'].mean()
# Out:
# County
# Bomet     19.0
# Nakuru    21.0
# Nyeri     17.0
# embu      20.0
# meru      18.0
# Name: Age, dtype: float64

# %% [markdown]
# ## **Handling missing Data**
# ### Introducing a missing value

# %%
df.loc[2, 'Salary'] = None
df
# Out:
#      Name  Age  County    Salary  occupation
# 0  Victor   20    embu   50000.0       pilot
# 1  Blessy   18    meru   70000.0       Nurse
# 2   Edwin   19   Bomet       NaN     Teacher
# 3    Vell   17   Nyeri   60000.0     Dentist
# 4   Allan   21  Nakuru  100000.0  politician

# %%
print ('\nDataFrame with missing value:')
df
# Out:
# DataFrame with missing value:
#      Name  Age  County    Salary  occupation
# 0  Victor   20    embu   50000.0       pilot
# 1  Blessy   18    meru   70000.0       Nurse
# 2   Edwin   19   Bomet       NaN     Teacher
# 3    Vell   17   Nyeri   60000.0     Dentist
# 4   Allan   21  Nakuru  100000.0  politician

# %% [markdown]
# ## supress warning

# %%
import warnings
warnings.simplefilter('ignore')

# %%
print ('\nFilling missing values with mean salary:')
df['Salary'].fillna(df['Salary'].mean(), inplace=True)
df
# Out:
# Filling missing values with mean salary:
#      Name  Age  County    Salary  occupation
# 0  Victor   20    embu   50000.0       pilot
# 1  Blessy   18    meru   70000.0       Nurse
# 2   Edwin   19   Bomet   70000.0     Teacher
# 3    Vell   17   Nyeri   60000.0     Dentist
# 4   Allan   21  Nakuru  100000.0  politician

# %% [markdown]
# ## Introducing a missing value

# %%
df.loc[2,'occupation'] = None
df
# Out:
#      Name  Age  County    Salary  occupation
# 0  Victor   20    embu   50000.0       pilot
# 1  Blessy   18    meru   70000.0       Nurse
# 2   Edwin   19   Bomet   70000.0        None
# 3    Vell   17   Nyeri   60000.0     Dentist
# 4   Allan   21  Nakuru  100000.0  politician

# %% [markdown]
# ## Replace the missing value(Categorical)

# %%
df['occupation'].fillna(df['occupation'].mode()[0], inplace=True)
df
# Out:
#      Name  Age  County    Salary  occupation
# 0  Victor   20    embu   50000.0       pilot
# 1  Blessy   18    meru   70000.0       Nurse
# 2   Edwin   19   Bomet   70000.0     Dentist
# 3    Vell   17   Nyeri   60000.0     Dentist
# 4   Allan   21  Nakuru  100000.0  politician

# %% [markdown]
# # **EXERCISE**
# ## Create DataFrame

# %%
# Method 1: FROM A DICTIONARY
data={'Name':['Allan','Victor','Blessy','Vell','Edwin'],
      'Age':[20,18,19,22,30],
      'Counties':['Kiambu','Meru','Embu','Tharaka','Nairobi'],
      'Salary':[10000,20000,90000,120000,70000],
      'Universities':['Chuka','UON','KU','MKU','Embu U']}
df=pd.DataFrame(data)
print(df)
# Out:
#      Name  Age Counties  Salary Universities
# 0   Allan   20   Kiambu   10000        Chuka
# 1  Victor   18     Meru   20000          UON
# 2  Blessy   19     Embu   90000           KU
# 3    Vell   22  Tharaka  120000          MKU
# 4   Edwin   30  Nairobi   70000       Embu U

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          5 non-null      object
#  1   Age           5 non-null      int64
#  2   Counties      5 non-null      object
#  3   Salary        5 non-null      int64
#  4   Universities  5 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 332.0+ bytes
